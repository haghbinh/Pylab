# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
#     <font face="Zar_Bd.ttf" size=5>
#         <div align=center>
#             <font face="IranNastaliq" size=10>
#                 <p dir="rtl" style="text-align: justify;"></p>
#                 <p dir="rtl" style="text-align: justify;"></p>
# به نام خدا
#                 <p dir="rtl" style="text-align: justify;"></p>
#             </font>
#                <font color=#FF7500 face="IranNastaliq" size=30>
#                     <h3>درس هفدهم: کلاس‌ها - اشیاء    </h3>
#                </font>
#         </div>
#         <hr />
#         <style type="text/css" scoped>
#         p{
#         border: 1px solid #a2a9b1;background-color: #f8f9fa;display: inline-block;
#         };
#         </style>
#     </font>
# </div>

# %% [markdown]
# <h2 dir="rtl" style="text-align: justify;">کلاس و شیء در پایتون (Class & Object)</h2>
#
# <p dir="rtl" style="text-align: justify;">
# در پایتون، برنامه‌نویسی شیءگرا به شما اجازه می‌دهد داده‌ها و رفتارها را در قالب **کلاس‌ها** و **شیءها** سازمان‌دهی کنید.
# - <b>کلاس (Class)</b> الگوی تعریف یک نوع شیء است.
# - <b>شیء (Object)</b> نمونه واقعی از کلاس است که در حافظه ایجاد می‌شود.
# </p>
#
# <h2 dir="rtl" style="text-align: justify;">۱. تعریف کلاس و ایجاد شیء</h2>
#
# <p dir="rtl" style="text-align: justify;">
# برای تعریف یک کلاس از کلمه کلیدی <code>class</code> استفاده می‌کنیم و برای ایجاد شیء، کلاس را فراخوانی می‌کنیم.
# </p>

# %% [markdown]
# ### Some inbuilt classes in Python:
# * int
# * str
# * bool
# * float
# * list
# * dict
#
# Python defines how these classes look and behave.
#
# # DEFINING CLASSES
# Class is another name for type in Python.
# * A class may contain data in the form of fields. Fields are also called attributes.
# * Codes in the form of functions known as methods.

# %%
# class clas_name:
#     Initializer
#     attributes
#     methods()
#     Statments

# %%
class Demo:
	pass

D1=Demo()   #Instance or Object of the class Demo
print(D1)

# %% [markdown]
# The output of the print statement is <__main__.Demo object at 0x029B3150>. It tells us the address of the computer's memory where the object D1 is stored.

# %% [markdown]
# # Adding Attributes to a Class
#
# Let us consider a simple class called Rectangle which defi nes two instance variables **length** and **breadth**.

# %%
class Rectangle:
      length=0;      #Attribute length
      breadth=0;     #Attribute breadth

# %% [markdown]
# To create a Rectangle object we will use the following statement.

# %%
R1 = Rectangle () # Instance of Class

# %% [markdown]
# ### Accessing Attributes of an Object
#
# The syntax used to access the attributes of a class is:
#
# \<object>.\<attribute>

# %%
print(R1.length)     #Access attribute length
print(R1.breadth)    #Access attribute breadth
# Out:
# 0
# 0

# %% [markdown]
# The value can be anything like:
# * a Python primitive,
# * an inbuilt data type,
# * another object etc.
#
# It can even be a function or another class.

# %%
print('After reassigning the value of attributes')
print('Length = ',R1.length )
print('Breadth = ',R1.breadth )
print('Area of Rectangle is ',R1.length * R1.breadth)
# Out:
# After reassigning the value of attributes
# Length =  0
# Breadth =  0
# Area of Rectangle is  0

# %%
class pride():
	founded = '1374'
	country = 'Iran'
	color = 'White'

x=pride()
print(x.color)
print(x.country)
# Out:
# White
# Iran

# %% [markdown]
# # Adding Methods to a Class
#
# ### The Self-parameter
#
# To add methods to an existing class, the fi rst parameter for each method should be self. The self-parameter is used in the implementation of the method, but it is not used when the method is called. Therefore, the self-parameter references the object itself.

# %%
class MethodDemo:
	def Display_Message(self):
		print('Welcome to Python Programming')

ob1 = MethodDemo() 	#Instance of a class
ob1.Display_Message() #Calling Method
# Out:
# Welcome to Python Programming

# %%
import math
class Circle:
	def Calc_Area(self,radius):
		print('radius = ',radius)
		return math.pi*radius**2

ob1 = Circle()
print('Area of circle is ',ob1.Calc_Area(5))
# Out:
# radius =  5
# Area of circle is  78.53981633974483

# %%
class Rectangle:
	def Calc_Area_Rect(self,length,breadth):
	    print('length = ',length)
	    print('breadth = ',breadth)
	    return length*breadth


ob1 = Rectangle()
print('Area of Rectangle is ',ob1.Calc_Area_Rect(5,4))
# Out:
# length =  5
# breadth =  4
# Area of Rectangle is  20
